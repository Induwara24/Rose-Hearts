# %% [markdown]
# <a href="https://colab.research.google.com/github/Induwara24/Rose-Hearts/blob/main/Rose_Hearts_MobileNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# get data from google drive
# !gdown --id 1YxLmo9Nw5bLOGErfNkoWqUlEyWf2Rsq8
# Out:
# /usr/local/lib/python3.11/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1YxLmo9Nw5bLOGErfNkoWqUlEyWf2Rsq8
# From (redirected): https://drive.google.com/uc?id=1YxLmo9Nw5bLOGErfNkoWqUlEyWf2Rsq8&confirm=t&uuid=36645279-ce26-46e9-86fb-623f55197169
# To: /content/Mammogram_Dataset_KAU.zip
# 100% 606M/606M [00:10<00:00, 57.1MB/s]

# %%
# unzip the folder
# !unzip /content/Mammogram_Dataset_KAU.zip
# Out:
# Archive:  /content/Mammogram_Dataset_KAU.zip
#    creating: Mammogram_Dataset_KAU/
#    creating: Mammogram_Dataset_KAU/Benign/
#   inflating: Mammogram_Dataset_KAU/Benign/2013_BC003026_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2013_BC003026_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2013_BC003026_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2013_BC003026_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2013_BC009941_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2013_BC009941_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2013_BC009941_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2013_BC009941_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2013_BC010562_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2013_BC010562_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2013_BC010562_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2013_BC010562_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2013_BC011183_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2013_BC011183_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2013_BC011183_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2013_BC011183_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2013_BC011223_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2013_BC011223_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2013_BC011223_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2013_BC011223_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2013_BC011544_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2013_BC011544_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2013_BC011544_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2013_BC011544_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2014_BC012041_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2014_BC012041_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2014_BC012041_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2014_BC012041_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2014_BC012201_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2014_BC012201_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2014_BC012201_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2014_BC012201_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2016_BC003122_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2016_BC003122_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2016_BC003122_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2016_BC003122_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2016_BC005661_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2016_BC005661_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2016_BC005661_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2016_BC005661_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2016_BC011502_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2016_BC011502_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2016_BC011502_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2016_BC011502_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2016_BC014002_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2016_BC014002_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2016_BC016561_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2016_BC016561_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2016_BC016561_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2016_BC016561_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2016_BC016701_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2016_BC016701_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2016_BC016701_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2016_BC016701_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2016_BC016802_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2016_BC016802_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2016_BC016802_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2016_BC016802_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2016_BC016983_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2016_BC016983_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2016_BC016983_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2016_BC016983_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC0020201_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC0020201_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC0020201_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC0020201_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC0020381_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC0020381_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC0020381_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC0020381_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC0020742_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC0020742_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC0020742_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC0020742_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC0020781_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC0020781_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC0020781_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC0020781_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC005781_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC005781_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC005781_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC005781_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC006222_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC006222_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC006222_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC006222_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC009665_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC009665_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC009665_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC009665_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC011081_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC011081_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC011081_ CC_R_1.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC011081_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC011081_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC015902_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC015902_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC015902_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC015902_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC017441_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC017441_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC017441_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC017441_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC019421_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC019421_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC019421_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC019421_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC019521_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC019521_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC019521_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC019521_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC019621_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC019621_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC019621_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC019621_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC019681_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC019681_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC019681_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC019681_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC019782_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC019782_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC019782_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC019782_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC019861_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC019861_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC019861_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC019861_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC019911_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC019911_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC019911_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC019911_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC019915_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC019915_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC019915_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC019915_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC019922_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC019922_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC019922_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC019922_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC019941_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC019941_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC019941_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC019941_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC020083_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC020083_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC020083_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2017_BC020083_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0020302_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0020302_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0020302_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0020302_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021302_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021302_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021302_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021302_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021461_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021461_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021461_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021461_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021502_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021502_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021502_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021502_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021603_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021603_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021603_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021603_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021643_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021643_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021643_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021643_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021663_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021663_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021663_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021663_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021726_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021726_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021726_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021726_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021730_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021730_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021730_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021730_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021761_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021761_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021761_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021761_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021822_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021822_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021822_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021822_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021823_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021823_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021823_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021823_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021825_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021825_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021825_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021825_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021881_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021881_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021881_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021881_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021882_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021882_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021882_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021882_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021884_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021884_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021884_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021884_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021921_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021921_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021921_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021921_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021964_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021964_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021964_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021964_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021965_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021965_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021965_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0021965_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0022021_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0022021_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0022021_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0022021_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0022022_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0022022_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0022022_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0022022_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0022030_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0022030_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0022030_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0022030_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0022121_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0022121_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0022121_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0022121_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0022122_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0022122_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0022122_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0022122_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0022143_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0022143_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0022143_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0022143_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0022261_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0022261_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0022261_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0022261_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0022461_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0022461_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0022461_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0022461_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0022502_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0022502_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0022502_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0022502_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0022661_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0022661_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0022661_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0022661_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0022841_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0022841_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0022841_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0022841_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0022845_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0022845_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0022845_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0022845_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0022862_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0022862_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0022862_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0022862_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0022941_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0022941_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0022941_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0022941_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0023121_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0023121_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0023121_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0023121_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0023181_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0023181_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0023181_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0023181_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0023221_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0023221_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0023221_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0023221_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0023321_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0023321_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0023321_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0023321_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0023322_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0023322_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0023322_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0023322_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0024022_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0024022_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0024022_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0024022_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0024204_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0024204_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0024204_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC0024204_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC004661_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC004661_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC004661_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC004661_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC009783_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC009783_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC009783_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC009783_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC013041_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC013041_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC013041_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC013041_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC013903_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC013903_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC013903_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC013903_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC015481_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC015481_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC015481_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC015481_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC015901_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC015901_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC015901_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC015901_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC017301_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC017301_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC017301_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC017301_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC018221_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC018221_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC018221_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2018_BC018221_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2019_BC0022845_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2019_BC0024463_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2019_BC0024704_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2019_BC0024704_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2019_BC0024704_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2019_BC0024704_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2019_BC0025182_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2019_BC0025182_ MLO_R_1.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2019_BC0025381_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2019_BC0025381_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2019_BC0025381_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2019_BC0025381_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2019_BC0025583_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2019_BC0025583_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2019_BC0025583_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2019_BC0025583_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2019_BC0026001_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2019_BC0026001_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2019_BC0026001_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2019_BC0026001_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2019_BC0026061_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2019_BC0026061_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2019_BC0026061_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2019_BC0026061_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2019_BC009723_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2019_BC009723_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2019_BC009723_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2019_BC009723_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2019_BC014002_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2019_BC014002_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2019_BC014002_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2019_BC014002_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2019_BC014021_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2019_BC014021_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2019_BC014021_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2019_BC014021_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2019_BC015722_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2019_BC015722_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2019_BC015722_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2019_BC015722_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2019_BC015825_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2019_BC015825_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2019_BC015825_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2019_BC015825_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2019_BC017261_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2019_BC017261_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2019_BC017261_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Benign/2019_BC017261_ MLO_R.jpg
#    creating: Mammogram_Dataset_KAU/Malignant/
#   inflating: Mammogram_Dataset_KAU/Malignant/2013_BC010881_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2013_BC010881_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2013_BC010881_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2013_BC010881_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2013_BC011123_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2013_BC011123_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2013_BC011123_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2013_BC011123_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2016_BC009024_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2016_BC009024_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2016_BC014181_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2016_BC014181_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2016_BC016501_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2016_BC016501_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2016_BC016501_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2016_BC016501_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2016_BC016741_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2016_BC016741_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2017_BC0020261_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2017_BC0020261_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2017_BC0020361_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2017_BC0020361_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2017_BC0020421_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2017_BC0020421_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2017_BC0020521_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2017_BC0020521_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2017_BC0020761_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2017_BC0020761_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2017_BC0020761_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2017_BC0020761_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2017_BC019561_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2017_BC019561_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2017_BC019602_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2017_BC019602_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2017_BC019721_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2017_BC019721_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2017_BC019721_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2017_BC019721_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2017_BC019744_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2017_BC019744_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2017_BC019822_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2017_BC019822_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC0021341_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC0021341_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC0021341_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC0021341_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC0021642_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC0021642_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC0021723_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC0021723_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC0021724_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC0021724_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC0021724_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC0021724_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC0021731_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC0021731_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC0021735_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC0021735_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC0021735_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC0021735_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC0021746_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC0021746_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC0021746_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC0021746_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC0021865_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC0021865_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC0021883_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC0021883_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC0021981_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC0021981_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC0022025_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC0022025_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC0022025_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC0022025_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC0022402_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC0022402_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC0022402_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC0022402_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC0022482_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC0022482_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC0022603_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC0022603_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC0022603_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC0022603_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC0023145_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC0023145_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC0023145_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC0023145_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC0023241_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC0023241_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC0023241_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC0023241_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC0024341_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC0024341_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC0024341_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC0024341_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC005421_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC005421_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC005421_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC005421_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC011725_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC011725_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC011725_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC011725_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC017121_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC017121_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC018161_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC018161_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC018161_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2018_BC018161_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2019_BC0021728_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2019_BC0021728_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2019_BC0021728_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2019_BC0021728_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2019_BC0024581_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2019_BC0024581_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2019_BC0024581_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2019_BC0024581_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2019_BC0024763_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2019_BC0024763_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2019_BC0025041_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2019_BC0025041_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2019_BC0025041_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Malignant/2019_BC0025041_ MLO_R.jpg
#    creating: Mammogram_Dataset_KAU/Normal/
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC000541_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC000541_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC000541_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC000541_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC001201_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC001201_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC001201_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC001201_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC001782_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC001782_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC001782_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC001782_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC001983_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC001983_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC001983_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC001983_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC002021_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC002021_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC002021_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC002021_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC002045_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC002045_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC002045_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC002045_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC002061_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC002061_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC002061_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC002061_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC002182_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC002182_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC002182_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC002182_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC002183_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC002183_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC002183_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC002183_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC002202_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC002202_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC002202_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC002202_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC002262_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC002262_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC002262_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC002262_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC002341_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC002341_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC002341_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC002341_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC002342_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC002342_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC002342_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC002342_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC002401_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC002401_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC002401_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC002401_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC002501_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC002501_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC002501_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC002501_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC002681_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC002681_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC002681_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC002681_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC002682_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC002682_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC002682_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC002682_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC002823_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC002823_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC002823_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC002823_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC003167_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC003167_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC003167_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC003167_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC004406_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC004406_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC004406_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC004406_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC004481_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC004481_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC004481_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC004481_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC007221_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC007221_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC007221_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC007221_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC009061_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC009061_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC009061_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC009061_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC009321_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC009321_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC009321_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC009321_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC009903_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC009903_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC009903_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC009903_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC009904_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC009904_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC009904_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC009904_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC009921_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC009921_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC009921_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC009921_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC009942_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC009942_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC009942_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC009942_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC010241_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC010241_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC010241_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC010241_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC010261_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC010261_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC010261_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC010261_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC010421_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC010421_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC010421_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC010421_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC010501_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC010501_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC010501_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC010501_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC010521_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC010521_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC010521_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC010521_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC010522_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC010522_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC010522_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC010522_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC010561_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC010561_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC010561_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC010561_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC010563_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC010563_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC010563_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC010563_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC010567_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC010567_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC010567_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC010567_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC010581_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC010581_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC010581_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC010581_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC010661_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC010661_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC010661_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC010661_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC010701_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC010701_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC010701_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC010721_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC010721_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC010721_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC010721_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC010741_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC010741_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC010741_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC010741_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC010742_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC010742_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC010742_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC010742_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC010761_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC010761_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC010761_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC010761_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC010781_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2013_BC010781_ CC_R.jpg
# ...
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0021421_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0021421_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0021421_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0021421_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0021442_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0021442_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0021442_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0021442_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0021581_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0021581_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0021581_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0021581_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0021641_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0021641_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0021641_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0021641_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0021662_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0021662_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0021662_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0021662_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0021747_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0021747_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0021747_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0021747_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0021821_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0021821_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0021821_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0021821_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0021922_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0021922_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0021922_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0021922_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0021962_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0021962_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0021962_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0021962_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0022033_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0022033_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0022033_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0022033_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0022062_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0022062_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0022062_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0022062_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0022341_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0022341_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0022341_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0022341_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0022361_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0022361_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0022361_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0022361_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0022381_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0022381_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0022381_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0022381_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0022462_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0022462_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0022462_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0022462_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0022481_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0022481_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0022481_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0022481_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0024521_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0024521_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0024521_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0024521_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0024641_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0024641_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0024641_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0024641_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0024703_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0024703_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0024703_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0024703_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0024721_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0024721_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0024721_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0024721_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0024763_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0024763_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0024841_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0024841_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0024841_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0024841_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0024901_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0024901_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0024901_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0024901_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0024921_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0024921_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0024921_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0024983_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0024983_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0024983_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0024983_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0025081_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0025081_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0025081_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0025081_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0025083_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0025083_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0025083_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0025083_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0025084_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0025084_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0025084_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0025084_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0025202_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0025202_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0025202_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0025202_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0025281_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0025281_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0025281_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0025281_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0025349_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0025349_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0025349_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0025349_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0025361_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0025361_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0025481_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0025481_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0025481_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0025481_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0025542_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0025542_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0025542_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0025542_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0025641_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0025641_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0025641_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0025641_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0025642_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0025642_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0025642_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0025642_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0025721_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0025721_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0025721_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0025721_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0025761_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0025761_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0025761_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0025761_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0025881_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0025881_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0025881_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0025881_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0025981_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0025981_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0025981_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC0025981_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC003026_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC003026_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC003026_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC003026_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC003201_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC003201_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC003201_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC003201_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC003301_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC003301_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC003301_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC003301_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC004102_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC004102_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC004102_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC004102_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC009041_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC009041_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC009041_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC009041_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC009804_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC009804_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC009804_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC009804_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC012521_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC012521_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC012521_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC012521_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC014181_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC014181_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC014181_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC014181_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC014481_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC014481_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC014481_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC014481_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC015743_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC015743_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC015743_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC015743_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC016561_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC016561_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC016561_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC016561_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC017021_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC017021_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC017021_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC017021_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC017221_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC017221_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC017221_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC017221_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC017241_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC017241_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC017241_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC017241_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC017301_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC017301_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC017301_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC017301_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC017944_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC017944_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC017944_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC017944_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC018121_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC018121_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC018121_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC018121_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC019102_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC019102_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC019102_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC019102_ MLO_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC019741_ CC_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC019741_ CC_R.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC019741_ MLO_L.jpg
#   inflating: Mammogram_Dataset_KAU/Normal/2019_BC019741_ MLO_R.jpg

# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import math
import shutil
import glob

# %%
# count the number of mammograms in the respective classes
ROOT_DIR = "/content/Mammogram_Dataset_KAU"
number_of_images = {}
for dir in os.listdir(ROOT_DIR):
    number_of_images[dir] = len(os.listdir(os.path.join(ROOT_DIR, dir)))

number_of_images.items()
# Out:
# dict_items([('Malignant', 124), ('Normal', 1865), ('Benign', 387)])

# %% [markdown]
# ##Spliting the data;
# - 70% for train data
# - 15% for test data
# - 15% for validation data

# %%
# create a function to split the data into separate folders
def splitDataFolder(path, split):

  if not os.path.exists("./"+path):
    os.mkdir("./"+path)

  for dir in os.listdir(ROOT_DIR):
    os.makedirs("./"+path+"/"+dir)
    for img in np.random.choice(a=os.listdir(os.path.join(ROOT_DIR, dir)), size=math.floor(split*number_of_images[dir]), replace=False):
      O = os.path.join(ROOT_DIR, dir, img)
      D = os.path.join("./"+path, dir)
      shutil.copy(O, D)
      os.remove(O)

  else:
    print(f"{path} folder already exists.")

# %%
# create the train folder
splitDataFolder("train", 0.7)
# Out:
# train folder already exists.

# %%
# create the validation folder
splitDataFolder("val", 0.15)
# Out:
# val folder already exists.

# %%
# create the test folder
splitDataFolder("test", 0.15)
# Out:
# test folder already exists.

# %% [markdown]
# ###Preparing the data using Data Generator

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.applications.mobilenet import preprocess_input

# %%
# create function to preprocess images
def preprocessingImages1(path):
  """
  input: path to the folder
  output: preprocessed images
  """
  # data augmentation
  image_data = ImageDataGenerator(
      preprocessing_function=preprocess_input,
      shear_range=0.2,
      zoom_range=0.2,
      horizontal_flip=True
  )
  image = image_data.flow_from_directory(
      directory=path,
      target_size=(224,224),
      batch_size=32,
      class_mode="categorical"
  )
  return image

# %%
# preprocess train data
path = "/content/train"
train_data = preprocessingImages1(path)
# Out:
# Found 1661 images belonging to 3 classes.

# %%
# create function to preprocess images
def preprocessingImages2(path):
  """
  input: path to the folder
  output: preprocessed images
  """
  image_data = ImageDataGenerator(
      preprocessing_function=preprocess_input
  )
  image = image_data.flow_from_directory(
      directory=path,
      target_size=(224,224),
      batch_size=32,
      class_mode="categorical"
  )
  return image

# %%
# preprocess test data
path = "/content/test"
test_data = preprocessingImages2(path)
# Out:
# Found 355 images belonging to 3 classes.

# %%
# preprocess validation data
path = "/content/val"
val_data = preprocessingImages2(path)
# Out:
# Found 355 images belonging to 3 classes.

# %% [markdown]
# # Model build

# %%
# import libraries
import numpy as np
import matplotlib.pyplot as plt
from keras.layers import Flatten, Dense
from keras.models import Model, load_model
from keras.applications.mobilenet import MobileNet
import tensorflow as tf

# %%
# create the functional model
base_model = MobileNet(input_shape=(224,224,3), include_top=False)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf_no_top.h5
# 17225924/17225924 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# make sure the model is not re trained again
for layer in base_model.layers:
  layer.trainable = False

# %%
# summary of the base model
base_model.summary()
# Out:
# Model: "mobilenet_1.00_224"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1 (Conv2D)                  │ (None, 112, 112, 32)   │           864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1_bn (BatchNormalization)   │ (None, 112, 112, 32)   │           128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1_relu (ReLU)               │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_1 (DepthwiseConv2D)     │ (None, 112, 112, 32)   │           288 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_1_bn                    │ (None, 112, 112, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_1_relu (ReLU)           │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_1 (Conv2D)              │ (None, 112, 112, 64)   │         2,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_1_bn                    │ (None, 112, 112, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_1_relu (ReLU)           │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pad_2 (ZeroPadding2D)      │ (None, 113, 113, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_2 (DepthwiseConv2D)     │ (None, 56, 56, 64)     │           576 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_2_bn                    │ (None, 56, 56, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_2_relu (ReLU)           │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_2 (Conv2D)              │ (None, 56, 56, 128)    │         8,192 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_2_bn                    │ (None, 56, 56, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_2_relu (ReLU)           │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_3 (DepthwiseConv2D)     │ (None, 56, 56, 128)    │         1,152 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_3_bn                    │ (None, 56, 56, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_3_relu (ReLU)           │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_3 (Conv2D)              │ (None, 56, 56, 128)    │        16,384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_3_bn                    │ (None, 56, 56, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_3_relu (ReLU)           │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pad_4 (ZeroPadding2D)      │ (None, 57, 57, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_4 (DepthwiseConv2D)     │ (None, 28, 28, 128)    │         1,152 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_4_bn                    │ (None, 28, 28, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_4_relu (ReLU)           │ (None, 28, 28, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_4 (Conv2D)              │ (None, 28, 28, 256)    │        32,768 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_4_bn                    │ (None, 28, 28, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_4_relu (ReLU)           │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_5 (DepthwiseConv2D)     │ (None, 28, 28, 256)    │         2,304 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_5_bn                    │ (None, 28, 28, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_5_relu (ReLU)           │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_5 (Conv2D)              │ (None, 28, 28, 256)    │        65,536 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_5_bn                    │ (None, 28, 28, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_5_relu (ReLU)           │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pad_6 (ZeroPadding2D)      │ (None, 29, 29, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_6 (DepthwiseConv2D)     │ (None, 14, 14, 256)    │         2,304 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_6_bn                    │ (None, 14, 14, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_6_relu (ReLU)           │ (None, 14, 14, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_6 (Conv2D)              │ (None, 14, 14, 512)    │       131,072 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_6_bn                    │ (None, 14, 14, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_6_relu (ReLU)           │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_7 (DepthwiseConv2D)     │ (None, 14, 14, 512)    │         4,608 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_7_bn                    │ (None, 14, 14, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_7_relu (ReLU)           │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_7 (Conv2D)              │ (None, 14, 14, 512)    │       262,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_7_bn                    │ (None, 14, 14, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_7_relu (ReLU)           │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_8 (DepthwiseConv2D)     │ (None, 14, 14, 512)    │         4,608 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_8_bn                    │ (None, 14, 14, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_8_relu (ReLU)           │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_8 (Conv2D)              │ (None, 14, 14, 512)    │       262,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_8_bn                    │ (None, 14, 14, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_8_relu (ReLU)           │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_9 (DepthwiseConv2D)     │ (None, 14, 14, 512)    │         4,608 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_9_bn                    │ (None, 14, 14, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_9_relu (ReLU)           │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_9 (Conv2D)              │ (None, 14, 14, 512)    │       262,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_9_bn                    │ (None, 14, 14, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_9_relu (ReLU)           │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_10 (DepthwiseConv2D)    │ (None, 14, 14, 512)    │         4,608 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_10_bn                   │ (None, 14, 14, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_10_relu (ReLU)          │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_10 (Conv2D)             │ (None, 14, 14, 512)    │       262,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_10_bn                   │ (None, 14, 14, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_10_relu (ReLU)          │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_11 (DepthwiseConv2D)    │ (None, 14, 14, 512)    │         4,608 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_11_bn                   │ (None, 14, 14, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_11_relu (ReLU)          │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_11 (Conv2D)             │ (None, 14, 14, 512)    │       262,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_11_bn                   │ (None, 14, 14, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_11_relu (ReLU)          │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pad_12 (ZeroPadding2D)     │ (None, 15, 15, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_12 (DepthwiseConv2D)    │ (None, 7, 7, 512)      │         4,608 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_12_bn                   │ (None, 7, 7, 512)      │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_12_relu (ReLU)          │ (None, 7, 7, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_12 (Conv2D)             │ (None, 7, 7, 1024)     │       524,288 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_12_bn                   │ (None, 7, 7, 1024)     │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_12_relu (ReLU)          │ (None, 7, 7, 1024)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_13 (DepthwiseConv2D)    │ (None, 7, 7, 1024)     │         9,216 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_13_bn                   │ (None, 7, 7, 1024)     │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_13_relu (ReLU)          │ (None, 7, 7, 1024)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_13 (Conv2D)             │ (None, 7, 7, 1024)     │     1,048,576 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_13_bn                   │ (None, 7, 7, 1024)     │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_13_relu (ReLU)          │ (None, 7, 7, 1024)     │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,228,864 (12.32 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 3,228,864 (12.32 MB)

# %%
# combining our custom layer with the base model
x = Flatten()(base_model.output)
x = Dense(units=3, activation="softmax")(x)

# %%
# create the model
model = Model(base_model.input, x)

# %%
# summary of the custom model
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1 (Conv2D)                  │ (None, 112, 112, 32)   │           864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1_bn (BatchNormalization)   │ (None, 112, 112, 32)   │           128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1_relu (ReLU)               │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_1 (DepthwiseConv2D)     │ (None, 112, 112, 32)   │           288 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_1_bn                    │ (None, 112, 112, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_1_relu (ReLU)           │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_1 (Conv2D)              │ (None, 112, 112, 64)   │         2,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_1_bn                    │ (None, 112, 112, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_1_relu (ReLU)           │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pad_2 (ZeroPadding2D)      │ (None, 113, 113, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_2 (DepthwiseConv2D)     │ (None, 56, 56, 64)     │           576 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_2_bn                    │ (None, 56, 56, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_2_relu (ReLU)           │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_2 (Conv2D)              │ (None, 56, 56, 128)    │         8,192 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_2_bn                    │ (None, 56, 56, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_2_relu (ReLU)           │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_3 (DepthwiseConv2D)     │ (None, 56, 56, 128)    │         1,152 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_3_bn                    │ (None, 56, 56, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_3_relu (ReLU)           │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_3 (Conv2D)              │ (None, 56, 56, 128)    │        16,384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_3_bn                    │ (None, 56, 56, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_3_relu (ReLU)           │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pad_4 (ZeroPadding2D)      │ (None, 57, 57, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_4 (DepthwiseConv2D)     │ (None, 28, 28, 128)    │         1,152 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_4_bn                    │ (None, 28, 28, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_4_relu (ReLU)           │ (None, 28, 28, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_4 (Conv2D)              │ (None, 28, 28, 256)    │        32,768 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_4_bn                    │ (None, 28, 28, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_4_relu (ReLU)           │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_5 (DepthwiseConv2D)     │ (None, 28, 28, 256)    │         2,304 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_5_bn                    │ (None, 28, 28, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_5_relu (ReLU)           │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_5 (Conv2D)              │ (None, 28, 28, 256)    │        65,536 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_5_bn                    │ (None, 28, 28, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_5_relu (ReLU)           │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pad_6 (ZeroPadding2D)      │ (None, 29, 29, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_6 (DepthwiseConv2D)     │ (None, 14, 14, 256)    │         2,304 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_6_bn                    │ (None, 14, 14, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_6_relu (ReLU)           │ (None, 14, 14, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_6 (Conv2D)              │ (None, 14, 14, 512)    │       131,072 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_6_bn                    │ (None, 14, 14, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_6_relu (ReLU)           │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_7 (DepthwiseConv2D)     │ (None, 14, 14, 512)    │         4,608 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_7_bn                    │ (None, 14, 14, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_7_relu (ReLU)           │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_7 (Conv2D)              │ (None, 14, 14, 512)    │       262,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_7_bn                    │ (None, 14, 14, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_7_relu (ReLU)           │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_8 (DepthwiseConv2D)     │ (None, 14, 14, 512)    │         4,608 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_8_bn                    │ (None, 14, 14, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_8_relu (ReLU)           │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_8 (Conv2D)              │ (None, 14, 14, 512)    │       262,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_8_bn                    │ (None, 14, 14, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_8_relu (ReLU)           │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_9 (DepthwiseConv2D)     │ (None, 14, 14, 512)    │         4,608 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_9_bn                    │ (None, 14, 14, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_9_relu (ReLU)           │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_9 (Conv2D)              │ (None, 14, 14, 512)    │       262,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_9_bn                    │ (None, 14, 14, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_9_relu (ReLU)           │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_10 (DepthwiseConv2D)    │ (None, 14, 14, 512)    │         4,608 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_10_bn                   │ (None, 14, 14, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_10_relu (ReLU)          │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_10 (Conv2D)             │ (None, 14, 14, 512)    │       262,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_10_bn                   │ (None, 14, 14, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_10_relu (ReLU)          │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_11 (DepthwiseConv2D)    │ (None, 14, 14, 512)    │         4,608 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_11_bn                   │ (None, 14, 14, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_11_relu (ReLU)          │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_11 (Conv2D)             │ (None, 14, 14, 512)    │       262,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_11_bn                   │ (None, 14, 14, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_11_relu (ReLU)          │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pad_12 (ZeroPadding2D)     │ (None, 15, 15, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_12 (DepthwiseConv2D)    │ (None, 7, 7, 512)      │         4,608 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_12_bn                   │ (None, 7, 7, 512)      │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_12_relu (ReLU)          │ (None, 7, 7, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_12 (Conv2D)             │ (None, 7, 7, 1024)     │       524,288 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_12_bn                   │ (None, 7, 7, 1024)     │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_12_relu (ReLU)          │ (None, 7, 7, 1024)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_13 (DepthwiseConv2D)    │ (None, 7, 7, 1024)     │         9,216 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_13_bn                   │ (None, 7, 7, 1024)     │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_13_relu (ReLU)          │ (None, 7, 7, 1024)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_13 (Conv2D)             │ (None, 7, 7, 1024)     │     1,048,576 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_13_bn                   │ (None, 7, 7, 1024)     │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_13_relu (ReLU)          │ (None, 7, 7, 1024)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 50176)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 3)              │       150,531 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,379,395 (12.89 MB)
#  Trainable params: 150,531 (588.01 KB)
#  Non-trainable params: 3,228,864 (12.32 MB)

# %% [markdown]
# - Flatten layer and Dense layer are added to the bottom

# %%
#compile the model
model.compile(optimizer="adam", loss=tf.keras.losses.CategoricalCrossentropy(), metrics=["accuracy"])

# %%
# early stopping and model checkpoint
from keras.callbacks import EarlyStopping, ModelCheckpoint

mc = ModelCheckpoint(filepath="./best_model.h5", monitor="val_accuracy", verbose=1, save_best_only=True)
es = EarlyStopping(monitor="val_accuracy",  min_delta=0.01, verbose=1, patience=3)

cb = [es, mc]

# %% [markdown]
# ## Model training

# %%
hs = model.fit(
    train_data, # Changed 'generator' to directly use train_data
    steps_per_epoch=8,
    epochs=30,
    validation_data=val_data,
    validation_steps=16,
    callbacks=cb
)
# Out:
# Epoch 1/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5712 - loss: 5.1917
# Epoch 1: val_accuracy improved from -inf to 0.82817, saving model to ./best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 38s 4s/step - accuracy: 0.5863 - loss: 5.2430 - val_accuracy: 0.8282 - val_loss: 3.3399
# Epoch 2/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8204 - loss: 3.2860
# Epoch 2: val_accuracy did not improve from 0.82817
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 22s 3s/step - accuracy: 0.8195 - loss: 3.2737 - val_accuracy: 0.8254 - val_loss: 2.9622
# Epoch 3/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 651ms/step - accuracy: 0.8612 - loss: 3.3601
# Epoch 3: val_accuracy did not improve from 0.82817
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 25s 4s/step - accuracy: 0.8584 - loss: 3.3450 - val_accuracy: 0.7859 - val_loss: 3.2952
# Epoch 4/30
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8233 - loss: 2.8513
# Epoch 4: val_accuracy did not improve from 0.82817
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - accuracy: 0.8261 - loss: 2.7097 - val_accuracy: 0.8225 - val_loss: 3.0676
# Epoch 4: early stopping

# %% [markdown]
# ## Model accuracy

# %%
# load the best fit model
from keras.models import load_model
model = load_model("/content/best_model.h5")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
# Model accuracy
accuracy = model.evaluate(test_data)[1]
print(f"Test Accuracy: {round(accuracy*100, 2)}%")
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 14s 904ms/step - accuracy: 0.8262 - loss: 2.8687
# Test Accuracy: 81.69%

# %% [markdown]
# ## Model graphical interpretation

# %%
h = hs.history
h.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
# graph of accuracy vs val_accuracy
plt.plot(h["accuracy"])
plt.plot(h["val_accuracy"], c = "red")
plt.title("Accuracy vs Val_Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(["Accuracy", "Val_Accuracy"])
plt.show()

# %%
# graph of loss vs val_loss
plt.plot(h["loss"])
plt.plot(h["val_loss"], c = "red")
plt.title("Loss vs Val_Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(["Loss", "Val_Loss"])
plt.show()

# %% [markdown]
# ## Test the model with mammogram images

# %%
train_data.class_indices
# Out:
# {'Benign': 0, 'Malignant': 1, 'Normal': 2}

# %%
from keras.preprocessing.image import load_img, img_to_array

# %%
path = "/content/Mammogram_Dataset_KAU/Normal/2018_BC008361_ CC_R.jpg"
img = load_img(path, target_size=(224,224))

i = img_to_array(img)/255

input_arr = np.expand_dims(i, axis=0)
# Get the prediction probabilities using 'predict'
pred_probs = model.predict(input_arr)
# Get the class with the highest probability using argmax
pred = np.argmax(pred_probs, axis=1)
pred

if pred == 0:
  print("Prediction: Benign")
elif pred == 1:
  print("Prediction: Malignant")
else:
  print("Prediction: Normal")

# display the image
plt.imshow(input_arr[0])
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Prediction: Normal
